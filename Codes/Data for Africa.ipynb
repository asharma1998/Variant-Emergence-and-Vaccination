# %%
import pandas as pd

# Read the dataset from a CSV file
#file_path = "path/to/your/dataset.csv"  # Replace with the actual path to your dataset file
df = pd.read_csv(r'C:\Users\sharm\Documents\My Folder\Project_SARS\locations.csv')

# %%
# Create categories
rna_vaccines = ["Pfizer/BioNTech", "Moderna"]
adenovirus_vaccines = ["Oxford/AstraZeneca", "Janssen", "Sputnik V", "Sputnik Light", "Convidecia", "iNCOVACC"]
inactivated_virus_vaccines = ["Sinopharm BIBP", "CoronaVac", "Covaxin", "Valneva", "Sinopharm WIBP"]
subunit_vaccines = ["Novavax", "Sanofi-GSK", "Abdala", "EpiVacCorona", "Zifivax", "Soberana 02"]

# Function to categorize vaccines
def categorize_vaccine(vaccine):
    if any(brand.lower() in vaccine.lower() for brand in rna_vaccines):
        return "RNA Vaccines"
    elif any(brand.lower() in vaccine.lower() for brand in adenovirus_vaccines):
        return "Adenovirus Vector Vaccines"
    elif any(brand.lower() in vaccine.lower() for brand in inactivated_virus_vaccines):
        return "Inactivated Virus Vaccines"
    elif any(brand.lower() in vaccine.lower() for brand in subunit_vaccines):
        return "Subunit Vaccines"
    else:
        return "Uncategorized"

# Apply categorization to the 'vaccines' column
df['vaccine_category'] = df['vaccines'].apply(categorize_vaccine)

# Display the categorized DataFrame
print(df[['location', 'vaccines', 'vaccine_category']])
# Out:
#               location                                           vaccines  \
# 0          Afghanistan  CanSino, Covaxin, Johnson&Johnson, Moderna, Ox...
# 1              Albania  Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...
# 2              Algeria  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
# 3              Andorra       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 4               Angola                                 Oxford/AstraZeneca
# ..                 ...                                                ...
# 218              Wales       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 219  Wallis and Futuna                                            Moderna
# 220              Yemen  CanSino, Covaxin, Johnson&Johnson, Moderna, Ox...
# 221             Zambia  Johnson&Johnson, Oxford/AstraZeneca, Sinopharm...
# 222           Zimbabwe  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...
#
#                vaccine_category
# 0                  RNA Vaccines
# ...

# %%
df
# Out:
#               location  iso_code  \
# 0          Afghanistan       AFG
# 1              Albania       ALB
# 2              Algeria       DZA
# 3              Andorra       AND
# 4               Angola       AGO
# ..                 ...       ...
# 218              Wales  OWID_WLS
# 219  Wallis and Futuna       WLF
# 220              Yemen       YEM
# 221             Zambia       ZMB
# 222           Zimbabwe       ZWE
#
#                                               vaccines last_observation_date  \
# 0    CanSino, Covaxin, Johnson&Johnson, Moderna, Ox...            2023-11-26
# 1    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...            2023-09-10
# 2    Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...            2022-09-04
# 3         Moderna, Oxford/AstraZeneca, Pfizer/BioNTech            2023-09-24
# 4                                   Oxford/AstraZeneca            2023-11-19
# ..                                                 ...                   ...
# ...

# %%
#output_file_path = "r'C:\Users\sharm\Documents\My Folder\Project_SARS\categorized_dataset.csv"  # Replace with the desired output path
df.to_csv(r'C:\Users\sharm\Documents\My Folder\Project_SARS\categorized_dataset.csv', index=False)

# %%
african_countries = [
    "Algeria", "Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Central African Republic",
    "Chad", "Comoros", "Democratic Republic of the Congo", "Djibouti", "Egypt", "Equatorial Guinea", "Eswatini",
    "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Kenya", "Lesotho", "Liberia", "Libya",
    "Madagascar", "Malawi", "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger", "Nigeria",
    "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa",
    "South Sudan", "Sudan", "Tunisia", "Uganda", "Zambia", "Zimbabwe"
]

df_africa = df[df['location'].isin(african_countries)].copy()

print(df_africa[['location', 'vaccines', 'vaccine_category']])
# Out:
#                      location  \
# 2                     Algeria
# 4                      Angola
# 20                      Benin
# 26                   Botswana
# 31               Burkina Faso
# 32                    Burundi
# 34                   Cameroon
# 38   Central African Republic
# 39                       Chad
# 43                    Comoros
# 55                   Djibouti
# 59                      Egypt
# 62          Equatorial Guinea
# 64                   Eswatini
# 65                   Ethiopia
# 72                      Gabon
# 73                     Gambia
# 76                      Ghana
# 83                     Guinea
# 84              Guinea-Bissau
# 104                     Kenya
# 112                   Lesotho
# 113                   Liberia
# 114                     Libya
# 119                Madagascar
# 120                    Malawi
# 125                Mauritania
# 126                 Mauritius
# 133                   Morocco
# 134                Mozambique
# ...

# %%
df_africa.to_csv(r'C:\Users\sharm\Documents\My Folder\Project_SARS\categorized_dataset_africa.csv', index=False)
